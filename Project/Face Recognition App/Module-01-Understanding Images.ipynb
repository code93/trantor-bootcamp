# %%
import numpy as np #numerical python

# %%
# !pip install pillow
# Out:
# Requirement already satisfied: pillow in c:\users\shubham.birmi\freeai\facerecognition\class\module-1\freeai\lib\site-packages (8.2.0)

# %%
from PIL import Image # Python Image Library
import matplotlib
import cv2

# %%
# Reading Image Using PIL
img = Image.open('./data/Shubham-Birmi.jpg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512 at 0x2004F23AE20>

# %%
#Loading Using matplotlib RGB
img_mat = matplotlib.image.imread('./data/Shubham-Birmi.jpg')
img_mat
# Out:
# array([[[255, 255, 208],
#         [255, 255, 208],
#         [254, 255, 207],
#         ...,
#         [ 64,  54,  53],
#         [ 64,  54,  53],
#         [ 64,  54,  53]],
#
#        [[254, 255, 207],
#         [254, 255, 207],
#         [254, 255, 207],
#         ...,
#         [ 64,  54,  53],
#         [ 64,  54,  53],
#         [ 64,  54,  53]],
#
#        [[255, 255, 207],
#         [255, 254, 206],
#         [255, 254, 206],
#         ...,
#         [ 64,  54,  52],
#         [ 64,  54,  52],
#         [ 64,  54,  52]],
#
#        ...,
#
#        [[ 37,  27,  25],
#         [ 36,  28,  25],
#         [ 35,  27,  24],
#         ...,
#         [ 25,  20,  17],
#         [ 25,  20,  17],
#         [ 26,  21,  18]],
#
#        [[ 38,  28,  26],
#         [ 36,  28,  25],
#         [ 36,  28,  25],
#         ...,
#         [ 26,  21,  18],
#         [ 26,  21,  18],
#         [ 26,  21,  18]],
#
#        [[ 38,  28,  26],
#         [ 37,  29,  26],
#         [ 36,  28,  25],
#         ...,
#         [ 26,  21,  18],
#         [ 26,  21,  18],
#         [ 27,  22,  19]]], dtype=uint8)

# %%
# Read image using opencv
img_cv = cv2.imread('./data/Shubham-Birmi.jpg')
img_cv
# Out:
# array([[[208, 255, 255],
#         [208, 255, 255],
#         [207, 255, 254],
#         ...,
#         [ 53,  54,  64],
#         [ 53,  54,  64],
#         [ 53,  54,  64]],
#
#        [[207, 255, 254],
#         [207, 255, 254],
#         [207, 255, 254],
#         ...,
#         [ 53,  54,  64],
#         [ 53,  54,  64],
#         [ 53,  54,  64]],
#
#        [[207, 255, 255],
#         [206, 254, 255],
#         [206, 254, 255],
#         ...,
#         [ 52,  54,  64],
#         [ 52,  54,  64],
#         [ 52,  54,  64]],
#
#        ...,
#
#        [[ 25,  27,  37],
#         [ 25,  28,  36],
#         [ 24,  27,  35],
#         ...,
#         [ 17,  20,  25],
#         [ 17,  20,  25],
#         [ 18,  21,  26]],
#
#        [[ 26,  28,  38],
#         [ 25,  28,  36],
#         [ 25,  28,  36],
#         ...,
#         [ 18,  21,  26],
#         [ 18,  21,  26],
#         [ 18,  21,  26]],
#
#        [[ 26,  28,  38],
#         [ 26,  29,  37],
#         [ 25,  28,  36],
#         ...,
#         [ 18,  21,  26],
#         [ 18,  21,  26],
#         [ 19,  22,  27]]], dtype=uint8)

# %%
img_cv.shape
# Out:
# (512, 512, 3)

# %%
# BGR

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow(img_cv)

# %%
# rendering matplotlib array
plt.imshow(img_mat)

# %%
# displaying images
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow(img_mat) # rgb

# %%
plt.imshow(img_cv) #

# %%
img_mat.shape
# Out:
# (512, 512, 3)

# %%
# analysing image by matplotlib
# split array into three parts
r = img_mat[:,:,0] # red array
g = img_mat[:,:,1] # green array
b = img_mat[:,:,2] # blue array

# %%
r.shape, g.shape, b.shape
# Out:
# ((512, 512), (512, 512), (512, 512))

# %%
plt.subplot(1,3,1)
plt.imshow(r, cmap='gray')
plt.title('Red Region')
plt.subplot(1,3,2)
plt.imshow(g, cmap='gray')
plt.title('Green Region')
plt.subplot(1,3,3)
plt.imshow(b, cmap='gray')
plt.title('Blue Region')
plt.show()

# %%
# gray scale : 2d 
gray_MAT = cv2.cvtColor(img_mat,cv2.COLOR_RGB2GRAY)

# %%
# gray scale : 2d 
gray_CV = cv2.cvtColor(img_cv,cv2.COLOR_BGR2GRAY)

# %%
gray_MAT.shape, gray_CV.shape
# Out:
# ((512, 512), (512, 512))

# %%
plt.imshow(gray_MAT,cmap='gray')

# %%
plt.imshow(gray_CV,cmap='gray')
